# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrutiGhoniya/yolov8/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.5/719.5 kB 4.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Initialize a YOLO-World model
model = YOLO('yolov8n.pt')  # or select yolov8m/l-world.pt for different sizes

# Execute inference with the YOLOv8s-world model on the specified image
results = model.predict('/content/Screenshot 2024-03-08 161651.png')

# Show results
results[0].show()
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 106MB/s]
# image 1/1 /content/Screenshot 2024-03-08 161651.png: 352x640 7 persons, 2 buss, 1 backpack, 103.8ms
# Speed: 2.8ms preprocess, 103.8ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)

# %%
from PIL import Image
import cv2

# %%
# !pip install supervision
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 3.8 MB/s eta 0:00:00
# ...

# %%
import supervision as sv

# %%
model.set_classes([""])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-b5115ba07cd6> in <cell line: 1>()
# ----> 1 model.set_classes([""])
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1693             if name in modules:
#    1694                 return modules[name]
# -> 1695         raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#    1696
#    1697     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# AttributeError: 'YOLO' object has no attribute 'set_classes'

# %%
# !yolo detect predict model=yolov8n.pt source="/content/Gymkhana_aerial.mp4"
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (2118/7829) /content/Gymkhana_aerial.mp4: 384x640 1 airplane, 93.0ms
# video 1/1 (2119/7829) /content/Gymkhana_aerial.mp4: 384x640 1 airplane, 95.5ms
# video 1/1 (2120/7829) /content/Gymkhana_aerial.mp4: 384x640 (no detections), 102.0ms
# video 1/1 (2121/7829) /content/Gymkhana_aerial.mp4: 384x640 (no detections), 93.3ms
# video 1/1 (2122/7829) /content/Gymkhana_aerial.mp4: 384x640 (no detections), 110.4ms
# video 1/1 (2123/7829) /content/Gymkhana_aerial.mp4: 384x640 1 fork, 90.3ms
# video 1/1 (2124/7829) /content/Gymkhana_aerial.mp4: 384x640 1 fork, 93.9ms
# video 1/1 (2125/7829) /content/Gymkhana_aerial.mp4: 384x640 (no detections), 93.0ms
# video 1/1 (2126/7829) /content/Gymkhana_aerial.mp4: 384x640 (no detections), 96.9ms
# video 1/1 (2127/7829) /content/Gymkhana_aerial.mp4: 384x640 (no detections), 90.8ms
# video 1/1 (2128/7829) /content/Gymkhana_aerial.mp4: 384x640 (no detections), 94.3ms
# ...

# %%
# !ffmpeg -i {"/content/runs/detect/predict/Gymkhana_aerial.avi"} -vcodec libx264 {"detected.mp4"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
